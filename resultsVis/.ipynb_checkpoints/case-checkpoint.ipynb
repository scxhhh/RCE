# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate
import pickle

# %%
path_string = '../results/case.seqs'
with open(path_string,'rb') as f:
    data = pickle.load(f)

# %%
x1=[x for x in range(9)]
casea1=data[0]
caseranking1=data[1]
func11 = interpolate.interp1d(x1, casea1, kind='quadratic')
func12 = interpolate.interp1d(x1, caseranking1, kind='quadratic')
x11=np.arange(0,8,0.1)
casea11=func11(x11)
caseranking11=func12(x11)
plt.figure(figsize=(3,3))
ax = plt.gca()    
ax.spines['right'].set_color('none') 
ax.spines['top'].set_color('none')  
ax.xaxis.set_ticks_position('bottom')   
ax.yaxis.set_ticks_position('left') 
ax.spines['bottom'].set_position(('data', 0))  
ax.spines['left'].set_position(('data', 0))
ax.set_ylim(-50,50)
plt.plot(x11, casea11,color='black')
plt.plot(x11, caseranking11,color='black',linestyle=':',label='Ranking score')
plt.show()

# %%
x2=[x for x in range(80)]
casea2=data[2]
caseranking2=data[3]
plt.figure(figsize=(9,3))
ax = plt.gca()    
ax.spines['right'].set_color('none') 
ax.spines['top'].set_color('none')  
ax.xaxis.set_ticks_position('bottom')   
ax.yaxis.set_ticks_position('left') 
ax.spines['bottom'].set_position(('data', 0))  
ax.spines['left'].set_position(('data', 0))
ax.set_ylim(-50,50)
plt.plot(x2, casea2,color='black')
plt.plot(x2, caseranking2,color='black',linestyle=':',label='Ranking score')
plt.show()

# %%
x3=[x for x in range(50)]
casea3=data[4]
caseranking3=data[5]
plt.figure(figsize=(6,3))
ax = plt.gca()    
ax.spines['right'].set_color('none') 
ax.spines['top'].set_color('none')  
ax.xaxis.set_ticks_position('bottom')   
ax.yaxis.set_ticks_position('left') 
ax.spines['bottom'].set_position(('data', 0))  
ax.spines['left'].set_position(('data', 0))
ax.set_ylim(-50,50)
plt.plot(x3, casea3,color='black')
plt.plot(x3, caseranking3,color='black',linestyle=':',label='Ranking score')
plt.show()
